# %%
import pandas as pd
import os 

path = 'CTA ridership/'
ls_file = os.listdir(path )

for file in ls_file:
    try: 
        df_iter = pd.read_csv(path+file)
        print('*'*30 + file)
        print(df_iter.describe() )
        print(df_iter.describe(include=['object']))

    except ValueError:
        print ('$'*30 + 'error: ' + file)
# for iter_num, chunk in enumerate(df_iter, 1):
#     print(f'Processing iteration {iter_num}')







# df_iter.describe(include='all')
# Out:
# ******************************CTA_-_Ridership_-__L__Station_Entries_-_Monthly_Day-Type_Averages___Totals.csv
#          station_id  avg_weekday_rides  avg_saturday_rides  \
# count  30468.000000       30468.000000        30468.000000
# mean   40761.923986        3908.744509         2275.271482
# std      446.217945        3350.201233         2298.645987
# min    40010.000000           0.000000            0.000000
# 25%    40370.000000        1468.350000          817.750000
# 50%    40750.000000        2967.150000         1478.700000
# 75%    41150.000000        5123.175000         2916.800000
# max    41700.000000       24041.400000        19171.300000
#
#        avg_sunday-holiday_rides     monthtotal
# count              30468.000000   30468.000000
# mean                1656.183901  100975.290830
# std                 1797.371335   87764.944366
# min                    0.000000       0.000000
# 25%                  557.750000   37952.750000
# 50%                 1026.350000   75247.000000
# 75%                 2057.575000  132579.250000
# max                15982.000000  670496.000000
#        stationame month_beginning
# count       30468           30468
# unique        148             214
# top        Wilson      10/01/2017
# freq          215             146
# ******************************CTA_-_System_Information_-_List_of__L__Stops.csv
#             STOP_ID        MAP_ID  Historical Wards 2003-2015     Zip Codes  \
# count    300.000000    300.000000                  260.000000    300.000000
# mean   30156.940000  40788.466667                   28.507692  18294.773333
# std       93.018302    461.881765                   15.034193   6001.135300
# min    30001.000000  40010.000000                    2.000000   4301.000000
# 25%    30077.750000  40380.000000                   15.000000  14917.000000
# 50%    30156.500000  40785.000000                   26.000000  21191.000000
# 75%    30231.250000  41190.000000                   40.000000  21869.000000
# max    30386.000000  41700.000000                   53.000000  26618.000000
#
#        Community Areas  Census Tracts       Wards
# count       260.000000     260.000000  260.000000
# mean         34.515385     356.515385   23.115385
# std          18.812727     254.876099   13.958922
# min           1.000000       1.000000    1.000000
# 25%          25.000000      97.000000   10.000000
# 50%          33.000000     337.500000   23.000000
# 75%          40.000000     634.000000   36.000000
# max          76.000000     793.000000   50.000000
#        DIRECTION_ID            STOP_NAME STATION_NAME  \
# count           300                  300          300
# unique            4                  293          109
# top               S  Kedzie (Loop-bound)      Western
# freq            104                    3           10
#
#                    STATION_DESCRIPTIVE_NAME                 Location
# count                                   300                      300
# unique                                  145                      144
# top     Belmont (Red, Brown & Purple Lines)  (41.964273, -87.657588)
# freq                                      4                        4
# ******************************CTA_-_Ridership_-_Bus_Routes_-_Daily_Totals_by_Route.csv
#                rides
# count  796599.000000
# mean     6545.306681
# std      6508.799419
# min         0.000000
# 25%      1469.000000
# 50%      4203.000000
# 75%      9950.000000
# max     45177.000000
#          route        date daytype
# count   796599      796599  796599
# unique     185        6513       3
# top         76  12/03/2007       W
# freq      6513         153  616067
# ******************************CTA_-_Ridership_-_Annual_Boarding_Totals.csv
#               year           bus   paratransit          rail         total
# count    30.000000  3.000000e+01  3.000000e+01  3.000000e+01  3.000000e+01
# mean   2002.500000  3.172739e+08  8.204343e+05  1.844918e+08  5.025528e+08
# std       8.803408  4.541461e+07  7.273269e+05  3.388437e+07  4.265292e+07
# min    1988.000000  2.492312e+08  0.000000e+00  1.353697e+08  4.398738e+08
# 25%    1995.250000  2.951314e+08  0.000000e+00  1.566127e+08  4.752906e+08
# 50%    2002.500000  3.032696e+08  9.805645e+05  1.807674e+08  4.962537e+08
# 75%    2009.750000  3.246602e+08  1.241928e+06  2.087791e+08  5.250628e+08
# max    2017.000000  4.300895e+08  2.401397e+06  2.416761e+08  6.049609e+08
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$error: CTA_-_Ridership_-_Annual_Boarding_Totals.csv
# ******************************CTA_-_Ridership_-_Avg._Weekday_Bus_Stop_Boardings_in_October_2012.csv
#             stop_id     boardings    alightings
# count  11593.000000  11593.000000  11593.000000
# mean    8137.552747     90.958164     90.957785
# std     4931.401599    181.161159    175.251922
# min        1.000000      0.000000      0.000000
# 25%     3836.000000     10.500000     12.600000
# 50%     8083.000000     33.600000     38.200000
# 75%    11839.000000     92.000000     97.100000
# max    17710.000000   3366.300000   3418.300000
#        on_street cross_street routes month_beginning  daytype  \
# count      11593        11593  11591           11593    11593
# unique       365         1886    592               1        1
# top      WESTERN       KEDZIE      9      10/01/2012  Weekday
# freq         390           81    260           11593    11593
#
#                            location
# count                         11593
# unique                        11591
# top     (41.95420437, -87.64526199)
# freq                              2
# ******************************CTA_-_Ridership_-_Bus_Routes_-_Monthly_Day-Type_Averages___Totals.csv
#        Avg_Weekday_Rides  Avg_Saturday_Rides  Avg_Sunday-Holiday_Rides  \
# count       29669.000000        29669.000000              29669.000000
# mean         6736.905909         4274.913789               2969.877037
# std          6813.987885         5384.540117               3859.284702
# min             0.000000            0.000000                  0.000000
# 25%          1359.700000            0.000000                  0.000000
# 50%          4104.600000         1971.000000               1236.300000
# 75%         10541.600000         6915.200000               4884.500000
# max         37787.200000        30644.600000              24110.900000
#
#          MonthTotal
# count  2.966900e+04
# mean   1.757373e+05
# std    1.853069e+05
# min    1.000000e+00
# 25%    3.167300e+04
# 50%    1.018450e+05
# 75%    2.750340e+05
# max    1.058879e+06
#         route      routename Month_Beginning
# count   29669          29669           29669
# unique    183            189             214
# top         6  Kimball-Homan      09/01/2007
# freq      214            214             156
# ******************************ridership_by_stop.csv
#              STOPID     BOARDINGS    ALIGHTINGS           LAT           LON
# count  61119.000000  61119.000000  61119.000000  61119.000000  61119.000000
# mean    8153.877223     62.507415     62.507320     41.856542    -87.682557
# std     5078.562000    131.986066    128.350387      0.094509      0.062183
# min        1.000000      0.000000      0.000000     41.644158    -87.884297
# 25%     3659.000000      6.700000      8.000000     41.778192    -87.724594
# 50%     7903.000000     21.600000     24.300000     41.866988    -87.680829
# 75%    11869.500000     62.300000     65.000000     41.934153    -87.639501
# max    18415.000000   3366.300000   3418.300000     42.064700    -87.525699
#                MONTH  DAYTYPE ON_STREET CROSS_ST ROUTESSTPG
# count          61119    61119     61119    61119      61119
# unique             2        3       384     2039        780
# top     October 2012  Weekday   PULASKI   KEDZIE         82
# freq           31376    22402      1881      444       1071
# ******************************CTA_-_Ridership_-__L__Station_Entries_-_Daily_Totals.csv
#           station_id          rides
# count  927848.000000  927848.000000
# mean    40761.912856    3317.883331
# std       446.235124    3201.659185
# min     40010.000000       0.000000
# 25%     40370.000000    1125.000000
# 50%     40750.000000    2323.000000
# 75%     41150.000000    4356.000000
# max     41700.000000   36323.000000
#        stationname        date daytype
# count       927848      927848  927848
# unique         148        6513       3
# top         Racine  08/01/2011       W
# freq          6533         168  648325
# ******************************rail_station_entries.csv
#             SORT_ALL        ENTRIES
# count  625281.000000  625281.000000
# mean      101.799792    3484.610943
# std        62.346889    3342.684142
# min         1.000000       0.000000
# 25%        48.000000    1202.000000
# 50%        97.000000    2455.000000
# 75%       160.000000    4510.000000
# max       209.000000   36323.000000
#        SERVICE_DATE DAY_TYPE      LINE      BRANCH      STATION
# count        625281   625281    625281      625281       625281
# unique         4383        3         9          16          146
# top      12/11/2017        W  Red Line  North Main  Kedzie-Lake
# freq            145   436677    145401       83277         4383
